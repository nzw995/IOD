# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression II

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

sns.set_context("poster")
sns.set(rc={'figure.figsize': (15, 9)})
sns.set_style("whitegrid")

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
house_csv = pd.read_csv("dat/Sacramento_transactions.csv")

# %%
house_csv.shape
# Out:
# (985, 12)

# %%
# Check Null Values
house_csv.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
# Data Types
house_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
house_csv.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
house_csv['zip'] = house_csv['zip'].astype(str)

house_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    object
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 92.5+ KB

# %%
house_csv['sale_date'] = pd.to_datetime(house_csv['sale_date'].str.replace('EDT', 'UTC+4'))

house_csv.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                 sale_date  price   latitude   longitude
# 0  Residential 2008-05-21 00:00:00-04:00  59222  38.631913 -121.434879
# 1  Residential 2008-05-21 00:00:00-04:00  68212  38.478902 -121.431028
# 2  Residential 2008-05-21 00:00:00-04:00  68880  38.618305 -121.443839
# 3  Residential 2008-05-21 00:00:00-04:00  69307  38.616835 -121.439146
# 4  Residential 2008-05-21 00:00:00-04:00  81900  38.519470 -121.435768

# %%
# Extract day from sale_date and save in a new column
house_csv['day'] = house_csv['sale_date'].dt.day

house_csv.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                 sale_date  price   latitude   longitude  day
# 0  Residential 2008-05-21 00:00:00-04:00  59222  38.631913 -121.434879   21
# 1  Residential 2008-05-21 00:00:00-04:00  68212  38.478902 -121.431028   21
# 2  Residential 2008-05-21 00:00:00-04:00  68880  38.618305 -121.443839   21
# 3  Residential 2008-05-21 00:00:00-04:00  69307  38.616835 -121.439146   21
# 4  Residential 2008-05-21 00:00:00-04:00  81900  38.519470 -121.435768   21

# %%
# Describe Data
house_csv.describe().T
# Out:
#            count           mean            std          min            25%  \
# beds       985.0       2.911675       1.307932     0.000000       2.000000
# baths      985.0       1.776650       0.895371     0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243     0.000000     952.000000
# price      985.0  234144.263959  138365.839085  1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433    38.241514      38.482717
# longitude  985.0    -121.355982       0.138278  -121.551704    -121.446127
# day        985.0      18.217259       2.131239    15.000000      16.000000
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.626582      38.695589      39.020808
# longitude    -121.376220    -121.295778    -120.597599
# day            19.000000      20.000000      21.000000

# %%
house_csv[house_csv['beds'] == 0]
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 901  1530 TOPANGA LN Unit 204          LINCOLN  95648    CA     0      0
# 917            501 POPLAR AVE  WEST SACRAMENTO  95691    CA     0      0
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
#
#      sq__ft         type                 sale_date   price   latitude  \
# 73        0  Residential 2008-05-21 00:00:00-04:00  206000  38.631481
# 89        0  Residential 2008-05-21 00:00:00-04:00  244500  38.626671
# 100       0  Residential 2008-05-21 00:00:00-04:00  263500  38.553867
# 121       0  Residential 2008-05-21 00:00:00-04:00  320000  38.528575
# 126       0  Residential 2008-05-21 00:00:00-04:00  339500  38.602416
# ..      ...          ...                       ...     ...        ...
# 901       0        Condo 2008-05-15 00:00:00-04:00  138000  38.884150
# 917       0  Residential 2008-05-15 00:00:00-04:00  165000  38.584526
# 934       0        Condo 2008-05-15 00:00:00-04:00  188000  38.884170
# 947       0  Residential 2008-05-15 00:00:00-04:00  200100  38.569943
# 970       0  Residential 2008-05-15 00:00:00-04:00  224000  38.631026
#
#       longitude  day
# 73  -121.501880   21
# 89  -121.525970   21
# 100 -121.219141   21
# 121 -121.228600   21
# 126 -121.542965   21
# ..          ...  ...
# 901 -121.270277   15
# 917 -121.534609   15
# 934 -121.270222   15
# 947 -121.527539   15
# 970 -121.501879   15
#
# [108 rows x 13 columns]

# %%
house_csv.loc[house_csv['beds'] == 0, 'type'] = 'Bedless'

# %%
house_csv['type'].value_counts().plot(kind='bar')
plt.show()

# %%
# import the library
import folium
import pandas as pd

# Make an empty map
# 37.76, -122.45 is the initital location of SF, USA
m = folium.Map(location=[38.575764, -121.478851], zoom_start=10)

# I can add circle/marker one by one on the map
for i in range(0, len(house_csv.head(1000))):
    folium.Marker(
        location=[house_csv.iloc[i]['latitude'], house_csv.iloc[i]['longitude']]
    ).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b91f86a8f8284c52a881720eec9e2b7f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b91f86a8f8284c52a881720eec9e2b7f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b91f86a8f8284c52a881720eec9e2b7f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b91f86a8f8284c52a881720eec9e2b7f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.575764%2C%20-121.478851%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %% [markdown]
# ## ANSWER
# we are trying to predict price

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %% [markdown]
# ## ANSWER
# sq_ft, beds, baths, type

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
house_csv.corr()
# Out:
#                beds     baths    sq__ft     price  latitude  longitude  \
# beds       1.000000  0.839650  0.684041  0.342024 -0.291307  -0.053993
# baths      0.839650  1.000000  0.665690  0.416208 -0.235792   0.016582
# sq__ft     0.684041  0.665690  1.000000  0.333897 -0.383274  -0.177742
# price      0.342024  0.416208  0.333897  1.000000 -0.039573   0.284485
# latitude  -0.291307 -0.235792 -0.383274 -0.039573  1.000000   0.387925
# longitude -0.053993  0.016582 -0.177742  0.284485  0.387925   1.000000
# day       -0.003317  0.027585  0.052710  0.050196 -0.043809  -0.004985
#
#                 day
# beds      -0.003317
# baths      0.027585
# sq__ft     0.052710
# price      0.050196
# latitude  -0.043809
# longitude -0.004985
# day        1.000000

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# ANSWER

X = house_csv['sq__ft'].values.reshape(-1,1)
Y = house_csv['price']

linreg = LinearRegression()
linreg.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER
linreg.score(X, Y)
# Out:
# 0.11148717682951437

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training/test data
print('X_train is a %s' % type(X_train))
print('X_train rows: ', X_train.shape[0])
print(X_train[:10])

print('y_train is a %s' % type(y_train))
print('y_train rows: ', y_train.shape[0])
print(y_train[:10])
# Out:
# X_train is a <class 'numpy.ndarray'>
# X_train rows:  788
# [[   0]
#  [1595]
#  [1320]
#  [2222]
#  [   0]
#  [ 901]
#  [1280]
#  [1011]
#  [1503]
#  [ 901]]
# y_train is a <class 'pandas.core.series.Series'>
# y_train rows:  788
# 154    600000
# 295    339000
# 197    148500
# 329    582000
# 224    202500
# 370    121500
# 65     192067
# 614     85000
# 250    245000
# 24     125000
# Name: price, dtype: int64

# %%
# ANSWER
## Check training/test data
print('X_test is a %s' % type(X_test))
print('X_test rows: ', X_test.shape[0])
print(X_test[:10])

print('y_test is a %s' % type(y_test))
print('y_test rows: ', y_test.shape[0])
print(y_test[:10])
# Out:
# X_test is a <class 'numpy.ndarray'>
# X_test rows:  197
# [[1816]
#  [   0]
#  [1638]
#  [1013]
#  [1718]
#  [   0]
#  [1118]
#  [1351]
#  [3440]
#  [1032]]
# y_test is a <class 'pandas.core.series.Series'>
# y_test rows:  197
# 456    240000
# 850    533000
# 941    191675
# 347     85000
# 300    361948
# 934    188000
# 20     122000
# 395    158000
# 150    489332
# 607     65000
# Name: price, dtype: int64

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER
linreg = LinearRegression()
linreg.fit(X_train, y_train)

print(linreg.coef_, linreg.intercept_)
# Out:
# [56.64002524] 160798.26494457555

# %%
# ANSWER
linreg.score(X_test, y_test)
# Out:
# 0.09914352024816753

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
x = [[1204]]
Ypred = linreg.predict(x)
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  228992.85533528833

# %% [markdown]
# #### Find the error (Mean Squared Error)

# %%
# Predict price from X_test

y_preds = linreg.predict(X_test)

y_preds[:10]
# Out:
# array([263656.55078306, 160798.26494458, 253574.62629008, 218174.61051417,
#        258105.8283094 , 160798.26494458, 224121.81316452, 237318.93904578,
#        355639.95177518, 219250.77099376])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_preds, squared=True)
# Out:
# 15255192925.239183

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
