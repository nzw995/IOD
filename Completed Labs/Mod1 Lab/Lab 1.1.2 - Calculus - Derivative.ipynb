# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function such as f(x) = x**3 - attempt a variety of different functions
def f(x):
  
  return x**3

# %%
# test the function you defined above by simply print its value for some numbers
print('f(2) = ',f(2))
print('f(5) = ',f(5))
print('f(-3) = ',f(-3))
# Out:
# f(2) =  8
# f(5) =  125
# f(-3) =  -27

# %%
# plot f(x)
x = np.arange(-10,11,1)
y = f(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %%
# define derivative function
def derivative(x):
    # set delta (change in x) to a small value, say 0.001
    delta = 1.0/1000.0
    # define rise (the change in f(x))
    rise = (f(x + delta)) - f(x)
    slope = rise / delta
    return slope

# %%
# test the derivative function for some values of x
print('derivative of f(2) = ', derivative(3))
print('derivative of f(-7) = ', derivative(-7))
# Out:
# derivative of f(2) =  27.009000999996147
# derivative of f(-7) =  146.9790010000338

# %%
# plot derivative of f(x)
x = np.arange(-10,11,1)
y = derivative(x)

# %%
# plot both x and derivative of f(x)
x = np.arange(-10,11,1)
y = f(x)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)', color=color)
ax1.plot(x, y, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(which='major', axis='both', linestyle='--')

ax2 = ax1.twinx()  # fill in the blank - instantiate a second axes that shares the same x-axis

z = derivative(x)
color = 'tab:blue'
ax2.set_xlabel('x')
ax2.set_ylabel('derivative(x)', color='Darkblue')
ax2.plot(x, z, color='Darkblue')
ax2.tick_params(axis='z', labelcolor='Darkblue')
ax2.grid(which='major', axis='both', linestyle='--')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e21ec5a778b7> in <module>
#      19 ax2.set_ylabel('derivative(x)', color='Darkblue')
#      20 ax2.plot(x, z, color='Darkblue')
# ---> 21 ax2.tick_params(axis='z', labelcolor='Darkblue')
#      22 ax2.grid(which='major', axis='both', linestyle='--')
#      23
#
# F:\anaconda3\lib\site-packages\matplotlib\axes\_base.py in tick_params(self, axis, **kwargs)
#    3076
#    3077         """
# -> 3078         cbook._check_in_list(['x', 'y', 'both'], axis=axis)
#    3079         if axis in ['x', 'both']:
#    3080             xkw = dict(kwargs)
#
# F:\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_in_list(_values, **kwargs)
#    2264     for k, v in kwargs.items():
#    2265         if v not in values:
# -> 2266             raise ValueError(
#    2267                 "{!r} is not a valid value for {}; supported values are {}"
#    2268                 .format(v, k, ', '.join(map(repr, values))))
#
# ValueError: 'z' is not a valid value for axis; supported values are 'x', 'y', 'both'

# %%
ax2.plot?

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
