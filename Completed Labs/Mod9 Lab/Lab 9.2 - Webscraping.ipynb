# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.2: Web Scraping
# INSTRUCTIONS:
# - Read the guides and hints then create the necessary analysis and code to find an answer and conclusion for the task below.

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Find a Page
# Visit the [Fandom](http://fandom.wikia.com) website, find a wikia of your interest and pick a page to work with.

# %% [markdown]
# Open a web page with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the main text inside a few levels of HTML tags.

# %%
## Import Libraries

import regex as re

import pandas as pd

from urllib.parse import unquote
import urllib3
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
# specify the url
quote_page = 'https://www.nike.com/sg/launch'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
# query the website and return the html to the variable ‘page’
http = urllib3.PoolManager()
r = http.request('GET', quote_page)
if r.status == 200:
    page = r.data
    print('Type of the variable \'page\':', page.__class__.__name__)
    print('Page Retrieved. Request Status: %d, Page Size: %d' % (r.status, len(page)))
else:
    print('Some problem occurred. Request Status: %s' % r.status)
# Out:
# Type of the variable 'page': bytes
# Page Retrieved. Request Status: 200, Page Size: 646221

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')
print('Type of the variable \'soup\':', soup.__class__.__name__)
# Out:
# Type of the variable 'soup': BeautifulSoup

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="" data-country="sg" lang="en-GB">
#  <head>
#   <script id="newrelic-browser-agent-script" type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(26),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:

# %% [markdown]
# ### Check the HTML's Title

# %%
print('Title tag :%s:' % soup.title)
print('Title text:%s:' % soup.title.string)
# Out:
# Title tag :<title data-react-helmet="true">Nike SNKRS. Release Dates and Launch Calendar SG</title>:
# Title text:Nike SNKRS. Release Dates and Launch Calendar SG:

# %% [markdown]
# ### Find the main content
# - Check if it is possible to use only the relevant data

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
tag = 'div'
div = soup.find_all(tag)[0]
print('Type of the variable \'div\':', div.__class__.__name__)
# Out:
# Type of the variable 'div': Tag

# %%
# show the first 500 characters after removing redundant newlines
print(re.sub(r'\n\n+', '\n', div.text)[:500])

# %%
root = soup.find(id="root")
root
# Out:
# <div class="u-full-width u-full-height" id="root"><div class="u-full-width u-full-height"><div class="root-controller remove-outline" data-qa="root-controller"><span id="forcedOptimizely" style="display:none"></span><div class="main-layout" data-qa="category-experience"><div class="content-wrapper"><header><div class="d-sm-h d-lg-b"><section class="bg-white border-bottom-light-grey z10 top-nav"><div class="limit-max-width d-sm-h d-lg-flx"><div><a class="back-to-nike-link d-sm-ib va-sm-m pt2-sm pb2-sm prl7-sm d-sm-ib" href="https://www.nike.com/sg/en"><svg fill="#757575" height="10px" viewbox="0 0 185.4 300" width="12px"><path d="M160.4 300c-6.4 0-12.7-2.5-17.7-7.3L0 150 142.7 7.3c9.8-9.8 25.6-9.8 35.4 0 9.8 9.8 9.8 25.6 0 35.4L70.7 150 178 257.3c9.8 9.8 9.8 25.6 0 35.4-4.9 4.8-11.3 7.3-17.6 7.3z"></path></svg><span> <!-- -->Visit Nike.com<!-- --> </span></a></div><ul class="right-nav prl7-sm"><li class="member-nav-item d-sm-ib va-sm-m" data-qa="top-nav-user-menu"><button class="join-log-in text-color-grey prl3-sm pt2-sm pb2-sm fs12-sm d-sm-b" data-qa="top-nav-join-or-login-button" type="button">Join/Log In</button></li><li class="d-sm-ib va-sm-m help-list-container" data-qa="top-nav-help-link"><a class="non-dropdown-help-link small text-color-grey d-sm-ib va-sm-m ml2-sm mr2-sm" href="https://www.nike.com/sg/help">Help</a></li><li class="d-sm-ib va-sm-m help-list-container" data-qa="top-nav-cart-link"><a aria-label="Bag" class="hover-color-black text-color-grey bg-transparent prl3-sm pt2-sm pb2-sm m0-sm fs12-sm d-sm-b jewel-cart-container" href="https://www.nike.com/us/en/cart"><svg fill="#757575" height="18px" viewbox="0 0 25 32" width="18px"><path d="M23.92 8.64L3.84 5.76 1.2 4.08Q.88 3.92.6 4t-.48.36-.12.6.4.48l2.56 1.6 4.48 11.2-1.6 4q-.16.4.08.76t.64.36h16.48q.32 0 .56-.24t.24-.56-.24-.56-.56-.24H7.68l1.12-2.72h14.32q.32 0 .56-.2t.24-.52l.64-8.8q.08-.32-.12-.56t-.52-.32zM22 23.6q-.88 0-1.56.64t-.68 1.56.68 1.56T22 28t1.56-.64.68-1.56-.68-1.56T22 23.6zm-12.32 0q-.96 0-1.6.64t-.64 1.56.64 1.56 1.56.64 1.56-.64.64-1.56-.64-1.56-1.52-.64z"></path></svg></a></li><li class="d-sm-ib va-sm-m ml3-sm help-list-
silver and Black<!-- --> </h6></div><div class="cta-container bg-white pt6-sm pb7-sm prl12-sm pb8-sm pt8-lg ta-sm-c" data-qa="shop-now-cta"><img alt="loading" class="image-component d-sm-ib" data-qa="spinner-img" height="24" src="https://www.nike.com/assets/experience/dotcom-snkrs/ux/builds/spinner.8a5c38a4b31c99f34e449cde7ceb2d71.gif" style="opacity:0" title="loading" width="24"/></div></div></div></figcaption></div></div></figure><figure class="pb2-sm va-sm-t ncss-col-sm-12 ncss-col-md-6 ncss-col-lg-4 pb4-md prl0-sm prl2-md ncss-col-sm-6 ncss-col-lg-3 pb4-md prl2-md pl1-md pr0-md"><div class="product-card ncs ...

# %%
product = content.find_all('figure')

# %%
product_list = [t.find('a') for t in product]
product_href = [[t.get('aria-label'), 'https://www.nike.com%s'%t.get('href')] for t in product_list]

# %%
pd.DataFrame(product_href, columns=['product', 'url'])
# Out:
#                                              product  \
# 0  Air Jordan 4 x UNION LA 'Desert Moss' Release ...
# 1                        SNKRS Style: Pineapple Pack
# 2  Women's Air Max Furyosa 'Silver and Black' Rel...
# 3  Women's Air Jordan 1 Low OG 'Neutral Grey' Rel...
# 4          Air Force 1 'Pineapple Cork' Release Date
# 5  Women's Air Force 1 'Pineapple Canvas' Release...
# 6                 Air Max 96 II 'Beach' Release Date
# 7            Air Max 96 II 'Dark Denim' Release Date
# 8                                     Kickcheck 6.11
#
#                                                  url
# 0  https://www.nike.com/sg/launch/t/air-jordan-4-...
# 1  https://www.nike.com/sg/launch/t/snkrs-style-p...
# 2  https://www.nike.com/sg/launch/t/womens-air-ma...
# 3  https://www.nike.com/sg/launch/t/womens-air-jo...
# 4  https://www.nike.com/sg/launch/t/air-force-1-p...
# 5  https://www.nike.com/sg/launch/t/womens-air-fo...
# 6  https://www.nike.com/sg/launch/t/air-max-96-ii...
# 7  https://www.nike.com/sg/launch/t/air-max-96-ii...
# 8  https://www.nike.com/sg/launch/t/kickcheck-6-1...

# %%
from bs4 import BeautifulSoup
import requests
  
# sample website
sample_website = 'https://www.nike.com/sg/w/new-mens-shoes-3n82yznik1zy7ok'
  
# call get method to request the page
page = requests.get(sample_website)
  
# with the help of BeautifulSoup method and
# html parser created soup
nike_soup = BeautifulSoup(page.content, 'html.parser')

# %%
root = nike_soup.find(id='app-root')
root
# Out:
# <div id="app-root">
# <!-- START dotcom-nav configuration: shared -->
# <!-- Generated: c2542dc5-b3e3-479d-802f-adbce6624de2 @ 2021-06-14T18:10:05.709Z -->
# <script id="gen-nav-shared">
#         (function initDotcomNavShared() {
#           var messages = {"hf-geomismatch-chooseLocation":"Choose Location","hf-geomismatch-confirm":"Confirm","hf-geomismatch-message":"Update your location to shop products available in {country}","hf-geomismatch-prompt":"We think you are in {country}. Update your location?","hf-geomismatch-title":"Confirm your Location","hf-geoselection-title":"Select your Location","hf-header-label-carticon":"Bag Items","hf-header-label-countryicon":"Selected Location","hf_cookie-policy_banner_ok":"OK","hf_cookie_label_cookieSettings":"Cookie Settings","hf_cookie_label_done":"Done","hf_cookie_label_functional":"Functional","hf_cookie_label_performance":"Performance","hf_cookie_label_privacyPolicy":"Privacy & Cookie Policy","hf_cookie_label_socialMedia":"Social Media and Advertising","hf_cookie_label_yourCookieSettings":"Your Cookie Settings","hf_cookie_policy_banner":"Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {privacyAndCookiePolicyHTML}. You can adjust your preferences in {cookieSettingsHTML}.","hf_cookie_policy_banner_ok":"OK","hf_cookie_text_cookieAccept":"Yes, I Accept","hf_cookie_text_cookieReject":"No, I Don't Accept","hf_cookie_text_do_you_accept":"Do you accept these cookies and the processing of personal data involved?","hf_cookie_text_footer":"You can always change your preference by visiting 'Cookie Settings' at the bottom of the page. View {privacyAndCookiePolicyHTML} for full details.","hf_cookie_text_functional":"These cookies are required for basic site functionality and are therefore always enabled. These include cookies that allow you to be remembered as you explore the site within a single session or, if you request, from session to session. They help to make the bag and checkout process possible as well as assisting in security issues and conforming to regulations.","hf_cookie_text_information":"Privacy & Cookie Policy","hf_cookie_text_moreInformation":"More Information","hf_cookie_text_performance":"These cookies allow us to improve the site’s functionality by tracking usage on the website. In some cases these cookies can improve the speed with which we can process your request as they allow us to remember site preferences that you’ve selected. De-selecting these cookies may result in poorly tailored recommendations and slow site performance.","hf_cookie_text_policy":"Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalised ads. To get more information or amend your preferences, click the ‘More Information’ button or visit 'Cookie Settings' at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our {privacyAndCookiePolicyHTML}. Do you accept these cookies and the processing of personal data involved?","hf_cookie_text_socialMedia":"Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.","hf_cookie_text_socialMedia_2":"Social media cookies offer the possibility for you to connect to your social networks and share content from our website throug ...
#           var initialState = {"@unite":{"accessLevel":"X","additionalAddresses":[],"billingAddressGUID":null,"credentials":null,"error":null,"initialized":false,"profile":{},"sessionData":{},"shippingAddress":null,"swooshAccess":false,"view":"none","isModalOpen":false,"isSwooshUser":false,"isMobileVerified":false,"isLoggedIn":false,"facebookLoaded":false},"headerFooter":{"cartCount":0,"cartHref":null,"favoritesHref":null,"country":"SG","language":"en","locale":{"urlParam":"en","language":"en-GB","intl":"en-GB","langRegion":"en-GB","hreflang":"en-SG","default":true},"currency":"SGD","keyboardContext":true,"initialized":false,"headerGlyphClass":"g72-swoosh","inboxMessageCount":0,"env":"prod"},"visualSearch":{"visualSearchActive":false,"visualSearchFetching":false,"visualSearchFetched":null,"visualSearchItems":[],"visualSearchTotal":0,"visualSearchText":"","visualSearchSuggestions":[],"visualSearchSuggestion":-1},"headerOverlay":{"activeModalView":null,"overlayActive":false,"mobileMenuActive":false,"bannerActive":false,"geomismatchActive":false},"@carts":{"meta":{"appId":null,"config":{"validIds":[],"percent":0,"ignoreCartCount":false,"vasReady":false,"jcartOnly":false}},"locale":{},"cart":{"brand":"NIKE","channel":"NIKECOM","country":"US","currency":"USD","id":null,"items":[],"totals":{"quantity":0,"total":0,"subtotal":0},"links":{"self":{"ref":""}},"resourceType":"cart"},"totals":{"quantity":0,"total":0,"subtotal":0},"errors":[],"warnings":[],"inFlight":[],"itemIds":[],"bucketing":{"bucket":"jcart"}}};
#           var metadata = {"generationId":"c2542dc5-b3e3-479d-802f-adbce6624de2","timestamp":"2021-06-14T18:10:05.709Z","services":[]};
#           var navInstance = null;
#           var sdkInstance = null;
#           var queue = [initDotcomNav];
#           var experiments = [];
#           var experimentMap = {
#             'commerce-header': 'global_nav_rollout_apla:nav_v1',
#             'commerce-header-v2': 'global_nav_rollout_apla:nav_v2',
#           };
#
#           function initDotcomNav(dotcomNav) {
#             dotcomNav.init({
#               env: 'prod',
#               clientVersion: '4.48.8',
#               clientBaseUrl: 'https://www.nike.com/assets/dotcom/nav/4.48.8',
#               metadata: metadata,
#               messages: messages,
#               initialState: initialState,
#               country: 'SG',
#               language: 'en',
#               currency: 'SGD',
#               locale: {"urlParam":"en","language":"en-GB","intl":"en-GB","langRegion":"en-GB","hreflang":"en-SG","default":true},
#             });
#           }
#           function getQueue() {
#             return queue;
#           }
#           function NikeDotcomNavReady(callback) {
#             if (navInstance) {
#               callback(navInstance, sdkInstance);
#             } else if (queue.indexOf(callback) === -1) {
#               queue.push(callback);
#             }
#           }
#           function checkDOM(callback) {
#             if (document.readyState === "loading") {
#               document.addEventListener("DOMContentLoaded", callback);
#             } else {
#               callback();
#             }
#           }
#           function drainQueue(nav, sdk) {
#             checkDOM(function onDOMContentLoaded() {
#               navInstance = nav;
#               sdkInstance = sdk;
#               while(queue.length) {
#                 var next = queue.shift();
#                 next(nav, sdk);
#               }
#             });
#           }
#           function register(configurationName, metadata) {
#             NikeDotcomNavReady(function(nav) {
#               nav.register(configurationName, metadata);
#             });
#             if (experimentMap[configurationName]) {
#               experiments.push(experimentMap[configurationName]);
#             }
#           }
#           function getExperiments() {
#             return experiments;
#           }
#
#           NikeDotcomNavReady.getQueue = getQueue;
#           NikeDotcomNavReady.drainQueue = drainQueue;
#           NikeDotcomNavReady.register = register;
#           NikeDotcomNavReady.getExperiments = getExperiments;
#           window.NikeDotcomNavReady = NikeDotcomNavReady;
#         })();
#         </script>
# <script id="analytics-client" src="https://www.nike.com/assets/measure/data-capture/analytics-client.min.js" type="text/javascript"></script>
# <link href="https://www.nike.com/assets/dotcom/nav/4.48.8/dotcom-nav-client.css" rel="stylesheet"/>
# <script async="" src="https://www.nike.com/assets/dotcom/nav/4.48.8/dotcom-nav-client.js"></script>
# <script async="" src="https://www.nike.com/assets/dotcom/nav/experiments/dotcom-nav-experiments.js"></script>
# <!-- END dotcom-nav configuration: shared -->
# <script>
# if (!(checkFnArgs =>
#     // IE11 users will LOVE this concatenation
#     // eslint-disable-next-line prefer-template
#     document.getElementById('gen-nav-' + checkFnArgs[0]))(["shared"])) {
#   (fragmentPath => {
#   const error = new Error(
#     // eslint-disable-next-line prefer-template
#     'ESI fragment ' + fragmentPath + ' requested, but not found in client',
#   );
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     console.warn(error);
#     // eslint-disable-next-line no-undef
#     newrelic.noticeError(error, {
#       type: 'ESI_LOAD_ERROR',
#       fragment: fragmentPath,
#     });
#   } else {
#     throw error; // let another monitoring system catch the error.
#   }
# })('shared')
# } else {
#   (fragmentPath => {
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     // eslint-disable-next-line no-undef
#     newrelic.addPageAction('ESI_LOAD', { fragment: fragmentPath });
#   }
# })('shared')
# }
# </script>
# <div class="header-wrapper" id="navWrapper">
# <div id="cookie-banner-target"></div>
# <!-- START dotcom-nav configuration: commerce-header-v2 -->
# <!-- Generated: c2542dc5-b3e3-479d-802f-adbce6624de2 @ 2021-06-14T18:10:05.709Z -->
# <div id="gen-nav-commerce-header-v2">
# <a aria-label="Skip to main content" class="skip-to-content-link" href="#skip-to-content" tabindex="0">Skip to main content</a><div aria-hidden="true" class="pre-modal-window" data-pre="Modal"><div class="pre-modal"><button class="pre-modal-btn-close bg-transparent" data-var="closeBtn" style="display:none"><svg fill="#111" height="30px" viewbox="0 0 24 24" width="30px"><path d="M15.04 12L24 2.96 21.04 0 12 8.96 3.04 0 0 2.96 9.04 12 0 20.96 3.04 24 12 14.96 21.04 24 24 20.96z"></path></svg></button><div aria-modal="true" class="pre-modal-view" data-pre="UniteModal" data-view="uniteModal" role="dialog" style="display:none"><div class="unite-container"><div class="nike-unite" id="nike-unite-app-landing-view" style="display:none"></div><div class="nike-unite" id="nike-unite-confirm-password-reset-view" style="display:none"></div><div class="nike-unite" id="nike-unite-error-view" style="display:none"></div><div class="nike-unite" id="nike-unite-join-view" style="display:none"></div><div class="nike-unite" id="nike-unite-link-view" style="display:none"></div><div class="nike-unite" id="nike-unite-login-view" style="display:none"></div><div class="nike-unite" id="nike-unite-login-continuity-view" style="display:none"></div><div class="nike-unite" id="nike-unite-login-dropdown-view" style="display:none"></div><div class="nike-unite" id="nike-unite-mobile-verification-code-view" style="display:none"></div><div class="nike-unite" id="nike-unite-progressive-profile-view" style="display:none"></div><div class="nike-unite" id="nike-unite-reauth-view" style="display:none"></div><div class="nike-unite" id="nike-unite-reset-password-view" style="display:none"></div><div class="nike-unite" id="nike-unite-update-password-view" style="display:none"></div></div></div><div aria-describedby="PreCookieModalDesc" aria-labelledby="PreCookieTitleDesc" aria-modal="true" class="pre-modal-view" data-pre="CookieModalSimple" data-view="cookieModalSimple" role="dialog" style="display:none"><div class="pre-cookie-modal-body p6-sm"><header class="ncss-row"><div class="ncss-col-sm-12"><h3 class="border-bottom pb5-sm headline-2" id="PreCookieTitleDesc"><span id="hf_cookie_label_yourCookieSettings">Your Cookie Settings</span></h3></div></header><div class="ncss-row mt5-sm"><div class="ncss-col-sm-12"><p class="body-2" id="PreCookieModalDesc"><span id="hf_cookie_text_policy">Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalised ads. To get more information or amend your preferences, click the ‘More Information’ button or visit 'Cookie Settings' at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our <a class="pre-privacy-policy-link" href="http://agreementservice.svs.nike.com/sg/en_gb/rest/agreement?agreementType=privacyPolicy&amp;uxId=com.nike.commerce.nikedotcom.web&amp;country=sg&amp;language=en_gb&amp;requestType=redirect" rel="noopener noreferrer" target="_blank"><span id="hf_cookie_label_privacyPolicy">Privacy &amp; Cookie Policy</span></a>. Do you accept these cookies and the processing of personal data involved?</span></p></div></div><div class="ncss-row mt5-sm mb7-sm" data-var="twoCookieButtons"><div class="ncss-col-sm-12 ncss-col-md-6"><button class="ncss-btn-secondary-dark pt3-sm pb3-sm pt2-lg pb2-lg ta-sm-c u-full-width mb3-sm mb0-md" data-var="showMoreBtn1"><span id="hf_cookie_text_moreInformation">More Information</span></button></div><div class="ncss-col-sm-12 ncss-col-md-6"><button class="ncss-btn-primary-dark pt3-sm pb3-sm pt2-lg pb2-lg ta-sm-c u-full-width" data-var="acceptBtn1"><span id="hf_cookie_text_cookieAccept">Yes, I Accept</span></button></div></div><div class="mt5-sm mb5-sm mt2-md mb7-md" data-var="threeCookieButtons" style="display:none"><div class="ncss-row"><div class="ncss-col-sm-12 ncss-col-md-6"><button class ...
# <script>
#       NikeDotcomNavReady.register('commerce-header-v2', {"generationId":"c2542dc5-b3e3-479d-802f-adbce6624de2","timestamp":"2021-06-14T18:10:05.709Z","services":[{"name":"header","source":"iris","timestamp":{"global_header_menu":"2021-05-26T16:05:23.669Z","global_utility_menu":"2021-05-19T15:41:15.317Z"},"preview":false}]});
#       window.__MOBILENAV_STATE = {"0":[{"id":"0,0","path":"men","href":"https://www.nike.com/sg/men","label":"Men","classes":["is-static","is-header"]},{"id":"0,1","path":"women","href":"https://www.nike.com/sg/women","label":"Women","classes":["is-static","is-header"]},{"id":"0,2","path":"kids","href":"https://www.nike.com/sg/kids","label":"Kids","classes":["is-static","is-header"]},{"id":"0,3","path":"customise","href":"https://www.nike.com/sg/nike-by-you","label":"Customise","classes":["is-static","is-header"]},{"id":"0,4","path":"sale","href":"https://www.nike.com/sg/w/sale-3yaep","label":"Sale","classes":["is-static","is-header"]},{"id":"0,5","path":"launch","href":"https://www.nike.com/launch","label":"SNKRS","classes":["is-header"]}],"0,0":[{"id":"0,0,0","path":"featured","href":null,"label":"Featured","classes":["is-static","is-header"]},{"id":"0,0,1","path":"shoes","href":"https://www.nike.com/sg/w/mens-shoes-nik1zy7ok","label":"Shoes","classes":["is-static","is-header"]},{"id":"0,0,2","path":"clothing","href":"https://www.nike.com/sg/w/mens-clothing-6ymx6znik1","label":"Clothing","classes":["is-static","is-header"]},{"id":"0,0,3","path":"shop by sport","href":null,"label":"Shop By Sport","classes":["is-static","is-header"]},{"id":"0,0,4","path":"shop by brand","href":null,"label":"Shop By Brand","classes":["is-static","is-header"]},{"id":"0,0,5","path":"icons","href":null,"label":"Icons","classes":["is-static","is-header"]}],"0,0,0":[{"id":"0,0,0,0","path":"new releases","href":"https://www.nike.com/sg/w/new-mens-3n82yznik1","label":"New Releases","classes":["is-static"]},{"id":"0,0,0,1","path":"launch","href":"https://www.nike.com/launch","label":"SNKRS Launch Calendar","classes":[]},{"id":"0,0,0,2","path":"member access","href":"https://www.nike.com/sg/w/mens-member-access-4lbtyznik1","label":"Member Access","classes":["is-static"]},{"id":"0,0,0,3","path":"air force 1","href":"https://www.nike.com/sg/w/air-force-1-5sj3y","label":"Air Force 1","classes":["is-static"]},{"id":"0,0,0,4","path":"sustainable materials","href":"https://www.nike.com/sg/w/mens-sustainability-3ngp4znik1","label":"Sustainable Materials","classes":["is-static"]},{"id":"0,0,0,5","path":"low price shoes","href":"https://www.nike.com/sg/w/mens-low-price-shoes-7t83xznik1zy7ok","label":"Top Picks Under S$140","classes":[]},{"id":"0,0,0,6","path":"tie dye collection","href":"https://www.nike.com/sg/w/mens-tie-dye-collection-9y0ccznik1","label":"Tie Dye","classes":[]},{"id":"0,0,0,7","path":"summer shop","href":"https://www.nike.com/sg/w/mens-summer-shop-2etw7znik1","label":"Summer Shop","classes":["is-static"]},{"id":"0,0,0,8","path":"clearance","href":"https://www.nike.com/sg/w/mens-sale-3yaepznik1","label":"Sale","classes":["is-static"]}],"0,0,1":[{"id":"0,0,1,0","path":"newest sneakers","href":"https://www.nike.com/sg/w/new-mens-shoes-3n82yznik1zy7ok","label":"Newest Sneakers","classes":["is-static"]},{"id":"0,0,1,1","path":"all shoes","href":"https://www.nike.com/sg/w/mens-shoes-nik1zy7ok","label":"All Shoes","classes":["is-static"]},{"id":"0,0,1,2","path":"lifestyle","href":"https://www.nike.com/sg/w/mens-lifestyle-shoes-13jrmznik1zy7ok","label":"Lifestyle","classes":["is-static"]},{"id":"0,0,1,3","path":"running","href":"https://www.nike.com/sg/w/mens-running-shoes-37v7jznik1zy7ok","label":"Running","classes":["is-static"]},{"id":"0,0,1,4","path":"basketball","href":"https://www.nike.com/sg/w/mens-basketball-shoes-3glsmznik1zy7ok","label":"Basketball","classes":["is-static"]},{"id":"0,0,1,5","path":"jordan","href":"https://www.nike.com/sg/w/mens-jordan-shoes-37eefznik1zy7ok","label":"Jordan","classes":["is-static"]},{"id":"0,0,1,6","path":"soccer football","href":"https://www.nike.com/sg/w/mens-football-shoes-1gdj0znik1zy7ok","label":"Football","classes":["is-static"]},{"id":"0,0,1,7","path":"training and gym","href":"https://www.nike.com/sg/w/mens-training-gym-shoes-58jtoznik1zy7ok","label":"Gym and Training","classes":["is-static"]},{"id":"0 ...
#       </script>
# </div>
# <!-- END dotcom-nav configuration: commerce-header-v2 -->
# <script>
# if (!(checkFnArgs =>
#     // IE11 users will LOVE this concatenation
#     // eslint-disable-next-line prefer-template
#     document.getElementById('gen-nav-' + checkFnArgs[0]))(["commerce-header-v2"])) {
#   (fragmentPath => {
#   const error = new Error(
#     // eslint-disable-next-line prefer-template
#     'ESI fragment ' + fragmentPath + ' requested, but not found in client',
#   );
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     console.warn(error);
#     // eslint-disable-next-line no-undef
#     newrelic.noticeError(error, {
#       type: 'ESI_LOAD_ERROR',
#       fragment: fragmentPath,
#     });
#   } else {
#     throw error; // let another monitoring system catch the error.
#   }
# })('commerce-header-v2')
# } else {
#   (fragmentPath => {
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     // eslint-disable-next-line no-undef
#     newrelic.addPageAction('ESI_LOAD', { fragment: fragmentPath });
#   }
# })('commerce-header-v2')
# }
# </script>
# </div>
# <div id="react-root"><div class="css-obd9me" data-test="browseShell"><div class="css-gu8ceq" data-test="browseShellHeaderWrapper"><div></div></div><div class="d-lg-b"><div class="banner-spacer css-wvv134"></div></div><div class="wall css-xopv06" id="Wall"><div class="results css-12mrhwn css-z5nr6i css-17c0wg8 css-14em68c css-w7yhn1 lhn--closed"><div class="wall-header-offset"></div><div class="wall-breadcrumbs css-92i8r5"><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":"https://www.nike.com/sg/w/new-3n82y","name":"New Releases","position":1},{"@type":"ListItem","item":"https://www.nike.com/sg/w/new-shoes-3n82yzy7ok","name":"Shoes","position":2}]}</script><ol class="wall-breadcrumbs__list"><li><a class="css-hrsjq4 css-xhk1pl css-1t2ydyg wall-breadcrumbs__item is--link" data-ndx="0" href="https://www.nike.com/sg/w/new-3n82y">New Releases</a></li><span class="wall-breadcrumbs__separator">/</span><li><a class="css-hrsjq4 css-xhk1pl css-1t2ydyg wall-breadcrumbs__item is--link" data-ndx="1" href="https://www.nike.com/sg/w/new-shoes-3n82yzy7ok">Shoes</a></li></ol></div><div class="point css-n99xye header-position-anchor"></div><div class="header-position css-iqr4dm"><header class="wall-header css-3inwm8 is--mobile show--count"><div class="wall-header__content"><h1 class="wall-header__title css-hrsjq4 css-10ehrho css-yj4gxb" id="New-Men's-Shoes">New Men's Shoes<span class="wall-header__item_count">(73)</span></h1><nav class="wall-header__nav"><button aria-controls="left-nav" aria-describedby="New-Men's-Shoes" aria-expanded="false" aria-label="Show Filters New Men's Shoes" aria-pressed="false" class="wall-header__filters-btn css-hrsjq4 is--not-visible" type="button"><div class="icon-filters css-kd8nn6"></div></button></nav></div></header></div><div class="wall-header-offset"></div><div class="results__body"><div class="seo-nav-wrapper css-5ciliq"><div class="categories css-10qr031 is--desktop"><a aria-label="Category for Lifestyle" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--link" data-group-type="category" data-ndx="0" href="https://www.nike.com/sg/w/new-mens-lifestyle-shoes-13jrmz3n82yznik1zy7ok">Lifestyle</a><a aria-label="Category for Jordan" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--link" data-group-type="category" data-ndx="1" href="https://www.nike.com/sg/w/new-mens-jordan-shoes-37eefz3n82yznik1zy7ok">Jordan</a><a aria-label="Category for Running" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--link" data-group-type="category" data-ndx="2" href="https://www.nike.com/sg/w/new-mens-running-shoes-37v7jz3n82yznik1zy7ok">Running</a><a aria-label="Category for Basketball" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--link" data-group-type="category" data-ndx="3" href="https://www.nike.com/sg/w/new-mens-basketball-shoes-3glsmz3n82yznik1zy7ok">Basketball</a><button aria-label="Category for Training &amp; Gym" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--button" data-group-type="category" data-ndx="4" data-url="https://www.nike.com/sg/w/new-mens-training-gym-shoes-3n82yz58jtoznik1zy7ok" role="link" type="button">Training &amp; Gym</button><button aria-label="Category for Skateboarding" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--button" data-group-type="category" data-ndx="5" data-url="https://www.nike.com/sg/w/new-mens-skateboarding-shoes-3n82yz8mfrfznik1zy7ok" role="link" type="button">Skateboarding</button><button aria-label="Category for Golf" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--button" data-group-type="category" data-ndx="6" data-url="https://www.nike.com/sg/w/new-mens-golf-shoes-23q9wz3n82yznik1zy7ok" role="link" type="button">Golf</button><a aria-label="Category for Tennis" class="css-hrsjq4 css-xhk1pl css-1t2ydyg categories__item is--link" data-group-type="category" data-ndx="7" href="https://www.nike.com/sg/w/new ...
# <div id="react-fallback-root"></div>
# <!-- START dotcom-nav configuration: footer -->
# <!-- Generated: c2542dc5-b3e3-479d-802f-adbce6624de2 @ 2021-06-14T18:10:05.709Z -->
# <div id="gen-nav-footer"><nav aria-labelledby="HFGeoselectionDesc" aria-modal="true" class="hf-language-menu nc870" data-hfjs="LanguageMenu" data-version="4.48.8" role="dialog"><button aria-label="Close Menu" class="hf-modal-btn-close"><i class="g72-x-circle fs32-nav-sm nav-color-black"></i></button><div class="hf-language-menu-container p4-sm"><p class="nav-brand-alt hf-language-menu-title fs32-nav-sm lh12-nav-sm ta-sm-c p8-sm" id="HFGeoselectionDesc"><span id="hf-geoselection-title">Select your Location</span></p><div class="hf-accordion-group" data-pre="AccordionGroup"><div class="hf-accordion ncss-row is-open-md pb12-md" data-index="0" data-maxheight="363" data-pre="Accordion"><p class="hf-accordion-header"><button class="hf-accordion-button bg-transparent nav-brand-alt p2-sm mb2-md" data-var="toggleBtn"><span>Africa</span></button></p><div class="hf-accordion-body" data-var="body"><a class="hf-language-menu-item ncss-col-sm-12 ncss-col-md-4 ncss-col-lg-3" data-country="eg" data-hfjs="LanguageMenuItem" data-lang-region="en_GB" data-language="en" data-type="click_navCountrySelectionSuccess" href="https://www.nike.com/eg/" lang="en-EG" title="Egypt"><div class="ncss-col-sm-1 ncss-col-md-2 va-sm-m pl0-sm"><svg class="hf-geopin-icon" fill="#111" height="30px" viewbox="0 0 42 58" width="30px"><path d="M21 0C9.4 0 0 9.5 0 21.2 0 39.9 21 58 21 58s21-18.1 21-36.8C42 9.5 32.6 0 21 0zm0 31c-5.5 0-10-4.5-10-10s4.5-10 10-10 10 4.5 10 10-4.5 10-10 10z"></path></svg></div><div class="ncss-col-sm-10 ncss-col-md-9 va-sm-m lh14-nav-sm pt1-sm pl0-sm"><p class="nav-bold">Egypt</p><small class="nav-color-grey">English</small></div></a><a class="hf-language-menu-item ncss-col-sm-12 ncss-col-md-4 ncss-col-lg-3" data-country="ma" data-hfjs="LanguageMenuItem" data-lang-region="en_GB" data-language="en" data-type="click_navCountrySelectionSuccess" href="https://www.nike.com/ma/en/" lang="en-MA" title="Morocco"><div class="ncss-col-sm-1 ncss-col-md-2 va-sm-m pl0-sm"><svg class="hf-geopin-icon" fill="#111" height="30px" viewbox="0 0 42 58" width="30px"><path d="M21 0C9.4 0 0 9.5 0 21.2 0 39.9 21 58 21 58s21-18.1 21-36.8C42 9.5 32.6 0 21 0zm0 31c-5.5 0-10-4.5-10-10s4.5-10 10-10 10 4.5 10 10-4.5 10-10 10z"></path></svg></div><div class="ncss-col-sm-10 ncss-col-md-9 va-sm-m lh14-nav-sm pt1-sm pl0-sm"><p class="nav-bold">Morocco</p><small class="nav-color-grey">English</small></div></a><a class="hf-language-menu-item ncss-col-sm-12 ncss-col-md-4 ncss-col-lg-3" data-country="ma" data-hfjs="LanguageMenuItem" data-lang-region="fr_FR" data-language="fr" data-type="click_navCountrySelectionSuccess" href="https://www.nike.com/ma/" lang="fr-MA" title="Maroc"><div class="ncss-col-sm-1 ncss-col-md-2 va-sm-m pl0-sm"><svg class="hf-geopin-icon" fill="#111" height="30px" viewbox="0 0 42 58" width="30px"><path d="M21 0C9.4 0 0 9.5 0 21.2 0 39.9 21 58 21 58s21-18.1 21-36.8C42 9.5 32.6 0 21 0zm0 31c-5.5 0-10-4.5-10-10s4.5-10 10-10 10 4.5 10 10-4.5 10-10 10z"></path></svg></div><div class="ncss-col-sm-10 ncss-col-md-9 va-sm-m lh14-nav-sm pt1-sm pl0-sm"><p class="nav-bold">Maroc</p><small class="nav-color-grey">Français</small></div></a><a class="hf-language-menu-item ncss-col-sm-12 ncss-col-md-4 ncss-col-lg-3" data-country="za" data-hfjs="LanguageMenuItem" data-lang-region="en_GB" data-language="en" data-type="click_navCountrySelectionSuccess" href="https://www.nike.com/za/" lang="en-ZA" title="South Africa"><div class="ncss-col-sm-1 ncss-col-md-2 va-sm-m pl0-sm"><svg class="hf-geopin-icon" fill="#111" height="30px" viewbox="0 0 42 58" width="30px"><path d="M21 0C9.4 0 0 9.5 0 21.2 0 39.9 21 58 21 58s21-18.1 21-36.8C42 9.5 32.6 0 21 0zm0 31c-5.5 0-10-4.5-10-10s4.5-10 10-10 10 4.5 10 10-4.5 10-10 10z"></path></svg></div><div class="ncss-col-sm-10 ncss-col-md-9 va-sm-m lh14-nav-sm pt1-sm pl0-sm"><p class="nav-bold">South Africa</p><small class="nav-color-grey">English</small></div></a></div></div><div class="hf-accordion ncss-row is-open-md pb12-md" data-index="1" data-m ...
# <script>
#     NikeDotcomNavReady.register('footer', {"generationId":"c2542dc5-b3e3-479d-802f-adbce6624de2","timestamp":"2021-06-14T18:10:05.709Z","services":[{"name":"footer","source":"iris","timestamp":{"global_footer_menu":"2021-04-13T00:36:02.781Z"},"preview":false}]});
#     </script>
# <!-- END dotcom-nav configuration: footer -->
# <script>
# if (!(checkFnArgs =>
#     // IE11 users will LOVE this concatenation
#     // eslint-disable-next-line prefer-template
#     document.getElementById('gen-nav-' + checkFnArgs[0]))(["footer"])) {
#   (fragmentPath => {
#   const error = new Error(
#     // eslint-disable-next-line prefer-template
#     'ESI fragment ' + fragmentPath + ' requested, but not found in client',
#   );
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     console.warn(error);
#     // eslint-disable-next-line no-undef
#     newrelic.noticeError(error, {
#       type: 'ESI_LOAD_ERROR',
#       fragment: fragmentPath,
#     });
#   } else {
#     throw error; // let another monitoring system catch the error.
#   }
# })('footer')
# } else {
#   (fragmentPath => {
#   // eslint-disable-next-line no-undef
#   if (window.newrelic) {
#     // eslint-disable-next-line no-undef
#     newrelic.addPageAction('ESI_LOAD', { fragment: fragmentPath });
#   }
# })('footer')
# }
# </script>
# <div id="appConsoleRoot"></div>
# </div>

# %%
products_catalog = root.find(class_='product-grid__items css-yj4gxb css-r6is66 css-zndamd css-1u4idlj')
products_catalog
# Out:
# <div class="product-grid__items css-yj4gxb css-r6is66 css-zndamd css-1u4idlj"><div class="product-card css-1jijlv2 css-z5nr6i css-11ziap1 css-14d76vy css-dpr2cn product-grid__card" data-product-position="1"><div class="product-card__body" data-el-type="Card"><figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/air-zoom-pegasus-38-running-shoe-Hmsj6Q/CW7356-400">Nike Air Zoom Pegasus 38</a><a aria-label="Nike Air Zoom Pegasus 38" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/air-zoom-pegasus-38-running-shoe-Hmsj6Q/CW7356-400"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike Air Zoom Pegasus 38 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike Air Zoom Pegasus 38 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/d199515a-a0d1-4880-aba4-f92ddcbe7695/air-zoom-pegasus-38-running-shoe-Hmsj6Q.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Zoom Pegasus 38">Nike Air Zoom Pegasus 38</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div></figure></div></div><div class="product-card css-1jijlv2 css-z5nr6i css-11ziap1 css-14d76vy css-dpr2cn product-grid__card" data-product-position="2"><div class="product-card__body" data-el-type="Card"><figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/precision-5-basketball-shoe-dRqLr4/CW3403-100">Nike Precision 5</a><a aria-label="Nike Precision 5" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/precision-5-basketball-shoe-dRqLr4/CW3403-100"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike Precision 5 Basketball Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike Precision 5 Basketball Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/31d5f3fc-69f1-4248-af95-e8e6c9ac4ea9/precision-5-basketball-shoe-dRqLr4.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Precision 5">Nike Precision 5</div><div class="product-card__subtitle">Basketball Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$99</div></div></div></div></div></div></figure></div></div><div class="product-card css-1jijlv2 css-z5nr6i css-11ziap1 css-14d76vy ...

# %%
type(products_catalog)
# Out:
# bs4.element.Tag

# %%
products = products_catalog.find_all('figure')
products
# Out:
# [<figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/air-zoom-pegasus-38-running-shoe-Hmsj6Q/CW7356-400">Nike Air Zoom Pegasus 38</a><a aria-label="Nike Air Zoom Pegasus 38" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/air-zoom-pegasus-38-running-shoe-Hmsj6Q/CW7356-400"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike Air Zoom Pegasus 38 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike Air Zoom Pegasus 38 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/d199515a-a0d1-4880-aba4-f92ddcbe7695/air-zoom-pegasus-38-running-shoe-Hmsj6Q.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Zoom Pegasus 38">Nike Air Zoom Pegasus 38</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div></figure>,
#  <figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/precision-5-basketball-shoe-dRqLr4/CW3403-100">Nike Precision 5</a><a aria-label="Nike Precision 5" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/precision-5-basketball-shoe-dRqLr4/CW3403-100"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike Precision 5 Basketball Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike Precision 5 Basketball Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/31d5f3fc-69f1-4248-af95-e8e6c9ac4ea9/precision-5-basketball-shoe-dRqLr4.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike
shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/fdb16dc6-9570-4c55-93ba-830f426ff9c1/sb-nyjah-free-2-skate-shoe-cXNdqq.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike SB Nyjah Free 2">Nike SB Nyjah Free 2</div><div class="product-card__subtitle">Skate Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$149</div></div></div></div></div></div></figure>,
#  <figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/launch/r/DJ2536-900">Nike Air Force 1 '07 Premium</a><a aria-label="Nike Air Force 1 '07 Premium" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/launch/r/DJ2536-900"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike Air Force 1 '07 Premium Men's Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike Air Force 1 '07 Premium Men's Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/b5f72d55-b31b-4871-9be7-09c2a29768dd/air-force-1-07-shoe.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Launching in SNKRS</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Force 1 '07 Premium">Nike Air Force 1 '07 Premium</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$209</div></div></div></div></div></div></figure>,
#  <figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/react-infinity-run-flyknit-2-running-shoe-Qfh63N/CT2357-401">Nike React Infinity Run Flyknit 2</a><a aria-label="Nike React Infinity Run Flyknit 2" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/react-infinity-run-flyknit-2-running-shoe-Qfh63N/CT2357-401"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike React Infinity Run Flyknit 2 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike React Infinity Run Flyknit 2 Men's Running Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/4c1a7b57-0a1d-4b5a-a298-8e75e9c60901/react-infinity-run-flyknit-2-running-shoe-Qfh63N.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike React Infinity Run Flyknit 2">Nike React Infinity Run Flyknit 2</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$239</div></div></div></div></div></div></figure>,
#  <figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/react-infinity-run-fk-2-betrue-shoe-chD93L/DD6790-001">Nike React Infinity Run FK 2 BETRUE</a><a aria-label="Nike React Infinity Run FK 2 BETRUE" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/react-infinity-run-fk-2-betrue-shoe-chD93L/DD6790-001"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike React Infinity Run FK 2 BETRUE Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike React Infinity Run FK 2 BETRUE Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/12995e34-323e-4b61-8b85-51ff4db38710/react-infinity-run-fk-2-betrue-shoe-chD93L.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike React Infinity Run FK 2 BETRUE">Nike React Infinity Run FK 2 BETRUE</div><div class="product-card__subtitle">Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$239</div></div></div></div></div></div></figure>,
#  <figure><a class="product-card__link-overlay" href="https://www.nike.com/sg/t/skepta-air-max-tailwind-v-shoe-gQdzTc/CU1706-001">Nike x Skepta Air Max Tailwind V</a><a aria-label="Nike x Skepta Air Max Tailwind V" class="product-card__img-link-overlay" data-el-type="Hero" href="https://www.nike.com/sg/t/skepta-air-max-tailwind-v-shoe-gQdzTc/CU1706-001"><div class="wall-image-loader css-1la3v4n"><div><img alt="Nike x Skepta Air Max Tailwind V Men's Shoe" class="css-1fxh5tw product-card__hero-image" loading="lazy" sizes="" src="..." srcset=""/><noscript><img alt="Nike x Skepta Air Max Tailwind V Men's Shoe" class="css-1fxh5tw product-card__hero-image" height="400" loading="lazy" src="https://static.nike.com/a/images/c_limit,w_318,f_auto/t_product_v1/dd26f334-be6f-4c8c-b039-55f06b60447f/skepta-air-max-tailwind-v-shoe-gQdzTc.png" width="400"/></noscript></div></div></a><div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike x Skepta Air Max Tailwind V">Nike x Skepta Air Max Tailwind V</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$259</div></div></div></div></div></div></figure>]

# %%
type(products)
# Out:
# bs4.element.ResultSet

# %%
products_2 = [t.find(class_='product-card__info for--product disable-animations') for t in products]
products_2
# Out:
# [<div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Zoom Pegasus 38">Nike Air Zoom Pegasus 38</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Precision 5">Nike Precision 5</div><div class="product-card__subtitle">Basketball Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$99</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Legend Essential 2">Nike Legend Essential 2</div><div class="product-card__subtitle">Men's Training Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$89</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Jordan One Take II PF">Jordan One Take II PF</div><div class="product-card__subtitle">Basketball Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$159</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Force 1 '07 Craft">Nike Air Force 1 '07 Craft</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike SB BLZR Court">Nike SB BLZR Court</div><div class="product-card__subtitle">Skate Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$89</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Kepa Kai">Nike Kepa Kai</div><div class="product-card__subtitle">Men's Flip Flop</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$49</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Free Metcon 4">Nike Free Metcon 4</div><div class="product-card__subtitle">Training Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Ebernon Mid">Nike Ebernon Mid</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$115</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Zoom Terra Kiger 7">Nike Air Zoom Terra Kiger 7</div><div class="product-card__subtitle">Men's Trail Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$219</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Member Access</div><div class="product-card__titles"><div class="product-card__title" id="Nike Pegasus Trail 3">Nike Pegasus Trail 3</div><div class="product-card__subtitle">Men's Trail Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$209</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Max 97 SE">Nike Air Max 97 SE</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$259</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike ACG Air Deschütz +">Nike ACG Air Deschütz +</div><div class="product-card__subtitle">Sandal</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 3 Colors" class="product-card__product-count">3 Colours</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$115</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Wildhorse 7">Nike Wildhorse 7</div><div class="product-card__subtitle">Men's Trail Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div>,
#  None,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Jordan Delta 2">Jordan Delta 2</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$209</div></div></div></div></div></div>,
#  None,
#  None,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="NikeCourt Vapor Lite">NikeCourt Vapor Lite</div><div class="product-card__subtitle">Men's Hard Court Tennis Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$129</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike SB Nyjah Free 2">Nike SB Nyjah Free 2</div><div class="product-card__subtitle">Skate Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$149</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Launching in SNKRS</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Force 1 '07 Premium">Nike Air Force 1 '07 Premium</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$209</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike React Infinity Run Flyknit 2">Nike React Infinity Run Flyknit 2</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$239</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike React Infinity Run FK 2 BETRUE">Nike React Infinity Run FK 2 BETRUE</div><div class="product-card__subtitle">Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$239</div></div></div></div></div></div>,
#  <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike x Skepta Air Max Tailwind V">Nike x Skepta Air Max Tailwind V</div><div class="product-card__subtitle">Men's Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$259</div></div></div></div></div></div>]

# %%
products_2[0]
# Out:
# <div class="product-card__info for--product disable-animations"><div class=""><div class="product-card__messaging accent--color">Just In</div><div class="product-card__titles"><div class="product-card__title" id="Nike Air Zoom Pegasus 38">Nike Air Zoom Pegasus 38</div><div class="product-card__subtitle">Men's Running Shoe</div></div></div><div class="product-card__count-wrapper false undefined"><div class="product-card__count-item"><button class="product-card__colorway-btn" type="button"><div aria-label="Available in 1 Color" class="product-card__product-count">1 Colour</div></button></div></div><div class="product-card__animation_wrapper"><div class="product-card__price-wrapper"><div class="product-card__price"><div class="product-price__wrapper css-cl9118"><div class="product-price css-11s12ax is--current-price" data-test="product-price">S$199</div></div></div></div></div></div>

# %%
type(products_2[0])
# Out:
# bs4.element.Tag

# %%
products_2[0].find(class_='product-card__messaging accent--color').text
# Out:
# 'Just In'

# %%
products_2[0].find(class_='product-card__title').text
# Out:
# 'Nike Air Zoom Pegasus 38'

# %%
products_2[0].find(class_='product-card__subtitle').text
# Out:
# "Men's Running Shoe"

# %%
products_2[0].find(class_='product-card__product-count').text
# Out:
# '1 Colour'

# %%
products_2[0].find(class_='product-price css-11s12ax is--current-price').text
# Out:
# 'S$199'

# %%
type(products_2)
# Out:
# list

# %%
for t in products_2:
    if type(t) == type(None):
        print(t)
# Out:
# None
# None
# None

# %%
for t in products_2:
    if type(t) == type(None):
        products_2.remove(t)

# %%
for t in products_2:
    if type(t) == type(None):
        print(t)

# %%
for t in products_2:
    print(type(t))
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'>

# %%
products_3 = [[t.find(class_='product-card__messaging accent--color').text,
               t.find(class_='product-card__title').text,
               t.find(class_='product-card__subtitle').text,
               t.find(class_='product-card__product-count').text,
               t.find(class_='product-price css-11s12ax is--current-price').text
              ]for t in products_2]
pd.DataFrame(products_3, columns=['message', 'title', 'subtitle', 'color', 'price'])
# Out:
#                message                                title  \
# 0              Just In             Nike Air Zoom Pegasus 38
# 1              Just In                     Nike Precision 5
# 2              Just In              Nike Legend Essential 2
# 3              Just In                Jordan One Take II PF
# 4              Just In           Nike Air Force 1 '07 Craft
# 5              Just In                   Nike SB BLZR Court
# 6              Just In                        Nike Kepa Kai
# 7              Just In                   Nike Free Metcon 4
# 8              Just In                     Nike Ebernon Mid
# 9              Just In          Nike Air Zoom Terra Kiger 7
# 10       Member Access                 Nike Pegasus Trail 3
# 11             Just In                   Nike Air Max 97 SE
# 12             Just In              Nike ACG Air Deschütz +
# 13             Just In                     Nike Wildhorse 7
# 14             Just In                       Jordan Delta 2
# 15             Just In                 NikeCourt Vapor Lite
# 16             Just In                 Nike SB Nyjah Free 2
# 17  Launching in SNKRS         Nike Air Force 1 '07 Premium
# 18             Just In    Nike React Infinity Run Flyknit 2
# 19             Just In  Nike React Infinity Run FK 2 BETRUE
# 20             Just In     Nike x Skepta Air Max Tailwind V
#
#                         subtitle      color  price
# 0             Men's Running Shoe   1 Colour  S$199
# 1                Basketball Shoe   1 Colour   S$99
# 2            Men's Training Shoe   1 Colour   S$89
# 3                Basketball Shoe   1 Colour  S$159
# 4                     Men's Shoe   1 Colour  S$199
# 5                     Skate Shoe   1 Colour   S$89
# 6                Men's Flip Flop   1 Colour   S$49
# 7                  Training Shoe   1 Colour  S$199
# 8                     Men's Shoe   1 Colour  S$115
# 9       Men's Trail Running Shoe   1 Colour  S$219
# 10      Men's Trail Running Shoe   1 Colour  S$209
# 11                    Men's Shoe   1 Colour  S$259
# 12                        Sandal  3 Colours  S$115
# 13      Men's Trail Running Shoe   1 Colour  S$199
# 14                    Men's Shoe   1 Colour  S$209
# 15  Men's Hard Court Tennis Shoe   1 Colour  S$129
# 16                    Skate Shoe   1 Colour  S$149
# 17                    Men's Shoe   1 Colour  S$209
# 18            Men's Running Shoe   1 Colour  S$239
# 19                          Shoe   1 Colour  S$239
# 20                    Men's Shoe   1 Colour  S$259

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
